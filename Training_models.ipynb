# %%
from utils.metrics import dice_0, dice_1, dice_2, dice_3, dice_4, dice_5, dice_6, iou, categorical_dice, categorical_dice_loss
from utils.generate_data import load_train_test
from utils.functions import normalize, save_plots, train_segmentator, prediction, display_preds, save_images
from custom_layers.layers import MaxPoolingWithArgmax2D, MaxUnpooling2D

# %%
### UNET ###

# %%
from models.Unet import get_unet

# %%
train_segmentator(get_unet(),model_name='Unet')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/100
# 397/397 [==============================] - 82s 187ms/step - loss: 0.6762 - dice_0: 0.8891 - dice_1: 0.0515 - dice_2: 0.4487 - dice_3: 0.4082 - dice_4: 0.1842 - dice_5: 0.0491 - dice_6: 0.2385 - iou: 0.5282 - categorical_dice: 0.3236 - val_loss: 0.6600 - val_dice_0: 0.9290 - val_dice_1: 0.0242 - val_dice_2: 0.4134 - val_dice_3: 0.5600 - val_dice_4: 0.1437 - val_dice_5: 0.0509 - val_dice_6: 0.2585 - val_iou: 0.6182 - val_categorical_dice: 0.3396 - lr: 0.0010
# Epoch 2/100
# ...

# %%
from tensorflow import keras
new_model_Unet = keras.models.load_model('Segmentation_Unet.h5', custom_objects={"categorical_dice_loss":categorical_dice_loss, 'dice_0': dice_0, 'dice_1': dice_1, 'dice_2':dice_2,'dice_3': dice_3, 'dice_4':dice_4, 'dice_5':dice_5, 'dice_6':dice_6, 'iou':iou, "categorical_dice":categorical_dice})

# %%
pred_test_Unet=prediction(model= new_model_Unet,model_name="Unet")
# Out:
# ...
# 128/128 [==============================] - 10s 63ms/step

# %%
save_images(pred_test_Unet,4,model_name=' Unet')
save_images(pred_test_Unet,10,model_name='Unet')

# %%
display_preds(pred_test_Unet,i=10)

# %%
### ENET ###

# %%
from models.ENet import get_ENet

# %%
train_segmentator(get_ENet(),model_name='ENet')
# Out:
# Loading ENet
# /usr/local/lib/python3.10/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/100
# 397/397 [==============================] - 117s 201ms/step - loss: 0.7799 - dice_0: 0.6920 - dice_1: 0.0060 - dice_2: 0.4062 - dice_3: 0.2304 - dice_4: 0.1161 - dice_5: 0.0227 - dice_6: 0.0707 - iou: 0.3508 - categorical_dice: 0.2204 - val_loss: 0.7076 - val_dice_0: 0.9198 - val_dice_1: 0.0175 - val_dice_2: 0.4761 - val_dice_3: 0.2936 - val_dice_4: 0.1609 - val_dice_5: 0.0330 - val_dice_6: 0.1590 - val_iou: 0.6040 - val_categorical_dice: 0.2925 - lr: 0.0010
# Epoch 2/100
# ...

# %%
from tensorflow import keras
new_model_ENet = keras.models.load_model('Segmentation_ENet.h5', custom_objects={"categorical_dice_loss":categorical_dice_loss, "dice_0":dice_0, "dice_1":dice_1, "dice_2":dice_2, "dice_3":dice_3, "dice_4":dice_4, "dice_5":dice_5, "dice_6":dice_6, "iou":iou, "categorical_dice":categorical_dice})

# %%
pred_test_ENet=prediction(model= new_model_ENet,model_name="ENet")
# Out:
# ...
# 128/128 [==============================] - 10s 50ms/step

# %%
save_images(pred_test_ENet,4,model_name='ENet')
save_images(pred_test_ENet,10,model_name='ENet')

# %%
display_preds(pred_test_ENet,i=10)

# %%
### SCPPnet ###

# %%
from models.SCPPnet import get_SCPPnet

# %%
train_segmentator(get_SCPPnet(),model_name='SCPPnet')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/100
# 397/397 [==============================] - 103s 243ms/step - loss: 0.7703 - dice_0: 0.5322 - dice_1: 0.0179 - dice_2: 0.3101 - dice_3: 0.4550 - dice_4: 0.0963 - dice_5: 0.0293 - dice_6: 0.1689 - iou: 0.1817 - categorical_dice: 0.2298 - val_loss: 0.8049 - val_dice_0: 0.8813 - val_dice_1: 0.0311 - val_dice_2: 0.3129 - val_dice_3: 0.0413 - val_dice_4: 0.0615 - val_dice_5: 0.0223 - val_dice_6: 0.0462 - val_iou: 0.4515 - val_categorical_dice: 0.1950 - lr: 0.0010
# Epoch 2/100
# ...

# %%
from tensorflow import keras
new_model_SCPPnet = keras.models.load_model('Segmentation_SCPPnet.h5', custom_objects={"categorical_dice_loss":categorical_dice_loss, "dice_0":dice_0, "dice_1":dice_1, "dice_2":dice_2, "dice_3":dice_3, "dice_4":dice_4, "dice_5":dice_5, "dice_6":dice_6, "iou":iou, "categorical_dice":categorical_dice})

# %%
pred_test_SCPPnet=prediction(model= new_model_SCPPnet,model_name="SCPPnet")
# Out:
# ...
# 128/128 [==============================] - 14s 95ms/step

# %%
save_images(pred_test_SCPPnet,4,model_name='SCPPnet')
save_images(pred_test_SCPPnet,10,model_name='SCPPnet')

# %%
display_preds(pred_test_SCPPnet, i=10)

# %%
### VGG16_Unet ###

# %%
from models.VGG16_Unet import get_vgg16_unet

# %%
train_segmentator(model=get_vgg16_unet(input_shape=(256,256,3)), epochs=50, model_name='VGG16_Unet')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 397/397 [==============================] - 238s 560ms/step - loss: 0.6170 - dice_0: 0.8970 - dice_1: 0.0607 - dice_2: 0.5485 - dice_3: 0.5243 - dice_4: 0.2643 - dice_5: 0.0384 - dice_6: 0.3499 - iou: 0.5693 - categorical_dice: 0.3830 - val_loss: 0.7173 - val_dice_0: 0.9149 - val_dice_1: 0.0630 - val_dice_2: 0.5221 - val_dice_3: 0.4652 - val_dice_4: 0.0318 - val_dice_5: 0.0567 - val_dice_6: 0.0308 - val_iou: 0.6246 - val_categorical_dice: 0.2835 - lr: 0.0010
# Epoch 2/50
# ...

# %%
new_model_VGG16_Unet = keras.models.load_model('Segmentation_VGG16_Unet.h5', custom_objects={"categorical_dice_loss":categorical_dice_loss, "dice_0":dice_0, "dice_1":dice_1, "dice_2":dice_2, "dice_3":dice_3, "dice_4":dice_4, "dice_5":dice_5, "dice_6":dice_6, "iou":iou, "categorical_dice":categorical_dice})

# %%
pred_test_VGG16_Unet=prediction(model= new_model_VGG16_Unet,model_name="VGG16_Unet")
# Out:
# 32/32 [==============================] - 47s 924ms/step - loss: 0.4223 - dice_0: 0.9728 - dice_1: 0.1904 - dice_2: 0.7255 - dice_3: 0.7090 - dice_4: 0.4850 - dice_5: 0.3518 - dice_6: 0.6272 - iou: 0.8242 - categorical_dice: 0.5777

# %%
save_images(pred_test_VGG16_Unet,4,model_name='VGG16_Unet')
save_images(pred_test_VGG16_Unet,10,model_name='VGG16_Unet')

# %%
display_preds(pred_test_VGG16_Unet,i=10)

# %%
### ResNet50_Unet ###

# %%
from models.ResNet50_Unet import get_resnet50_unet

# %%
train_segmentator(model=get_resnet50_unet(), epochs=45, model_name='resnet50_unet')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/45
# 397/397 [==============================] - 398s 950ms/step - loss: 0.5896 - dice_0: 0.9131 - dice_1: 0.0679 - dice_2: 0.6231 - dice_3: 0.5546 - dice_4: 0.2536 - dice_5: 0.0752 - dice_6: 0.3887 - iou: 0.6141 - categorical_dice: 0.4105 - val_loss: 0.8960 - val_dice_0: 0.6881 - val_dice_1: 0.0373 - val_dice_2: 0.0059 - val_dice_3: 0.0113 - val_dice_4: 0.0178 - val_dice_5: 0.0043 - val_dice_6: 0.0022 - val_iou: 0.2526 - val_categorical_dice: 0.1042 - lr: 0.0010
# Epoch 2/45
# ...

# %%
from tensorflow import keras

# %%
new_model_resnet = keras.models.load_model('Segmentation_resnet50_unet.h5', custom_objects={"categorical_dice_loss":categorical_dice_loss, "dice_0":dice_0, "dice_1":dice_1, "dice_2":dice_2, "dice_3":dice_3, "dice_4":dice_4, "dice_5":dice_5, "dice_6":dice_6, "iou":iou, "categorical_dice":categorical_dice})

# %%
pred_test_Resnet50_Unet=prediction(model= new_model_resnet,model_name="resnet50_unet")
# Out:
# ...
# 128/128 [==============================] - 45s 306ms/step

# %%
save_images(pred_test_Resnet50_Unet,4,model_name='Resnet50_Unet')
save_images(pred_test_Resnet50_Unet,10,model_name='Resnet50_Unet')

# %%
display_preds(pred_test_Resnet50_Unet,i=10)

# %%
### SegNet ###

# %%
from models.SegNet import get_segnet

# %%
train_segmentator(model=get_segnet(), epochs=45, model_name='SegNet')

# %%
new_model_SegNet = keras.models.load_model('Segmentation_SegNet.h5', custom_objects={"MaxPoolingWithArgmax2D":MaxPoolingWithArgmax2D,"MaxUnpooling2D":MaxUnpooling2D, "categorical_dice_loss":categorical_dice_loss, "dice_0":dice_0, "dice_1":dice_1, "dice_2":dice_2, "dice_3":dice_3, "dice_4":dice_4, "dice_5":dice_5, "dice_6":dice_6, "iou":iou, "categorical_dice":categorical_dice})

# %%
pred_test_segnet=prediction(model= new_model_SegNet,model_name="SegNet")
# Out:
# ...
# 128/128 [==============================] - 44s 340ms/step

# %%
save_images(pred_test_segnet,4,model_name='SegNet50_Unet')
save_images(pred_test_segnet,10,model_name='SegNet50_Unet')

# %%
display_preds(pred_test_segnet,i=10)

# %%
################################
